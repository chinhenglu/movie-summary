# %% [markdown]
# # Abstractive summarization with T5
# This notebook is to run a baseline model for our final project.
# The notebook is [here](https://github.com/datasci-w266/2023-spring-main/blob/master/materials/lesson_notebooks/lesson_7_summarization_QA.ipynb)

# %%
# %pip install -q sentencepiece
# %pip install -q transformers
# %pip install -q rouge_score
# %pip install -q evaluate

# %%
import evaluate
from google.colab import output
import pprint
import timeit
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import os
import zipfile
from io import BytesIO, StringIO
import pprint
import operator
from pprint import pprint
from google.colab import drive
drive.mount('/content/drive')
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %%
# additional packages
import pprint

# %%
train_df = pd.read_csv('content/drive/MyDrive/w266/final_proj_data/train_wiki_bert_lemma.csv')
train_df.head()
# Out:
#    Unnamed: 0                                     title  imdb_id  \
# 0         221  Three Billboards Outside Ebbing Missouri  5027774
# 1         346                           Candle to Water  2387411
# 2         277                                      1917  8579674
# 3         420                     Friends with Benefits  1632708
# 4         315                                 Anonymous  1521197
#
#                                            bert_data  \
# 0  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 1  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 2  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 3  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 4  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
#
#                                           lemma_data  \
# 0  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 1  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 2  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 3  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 4  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
#
#                                         plot_outline  \
# 0  THREE BILLBOARDS OUTSIDE EBBING, MISSOURI is a...
# 1  To present five different contemporary stories...
# 2  April 1917, the Western Front. Two British sol...
# 3  Jamie Rellis (Mila Kunis) is a New York City h...
# 4  Edward De Vere, Earl of Oxford, is presented a...
#
#                                          bert_dialog  \
# 0   by\n Martin McDonagh\n You Red Welby?\n Yes, ...
# 1   \n Written by\n Nick Green\n Shooting draft (...
# 2   1917\n Written by\n Sam Mendes\n &\n Krysty W...
# 3   No. Not even close.\n I know. I'll be there.\...
# 4   \n Written by\n John Orloff\n up, etc...\n th...
#
#                                            bert_text
# 0   MILDRED HAYES, a woman in her early 50's, dri...
# 1   The car is stuck in rush-hour traffic, which ...
# 2   The following script takes place in real time...
# 3   He almost steps on a dog sleeping on the floo...
# 4   TITLES BEGIN over the SOUNDS of city traffic....

# %%
subset_train_df = train_df.sample(n=30, axis=0, random_state=266)
subset_train_df.shape
# Out:
# (30, 8)

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
lemma_text = []

for i in range(subset_train_df.shape[0]):
    raw_lemma = subset_train_df.iloc[i]['lemma_data']
    with open(raw_lemma, 'r') as file:
        text_data = file.read().replace('\n', '')
        text_data = ' '.join(str(text_data).split()[:1000])
        print(raw_lemma)
        print(len(text_data))
        print(text_data[:60])
        print(50*'*')
        lemma_text.append(text_data)
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas
# Out:
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/The Guard_1540133_lemmas.txt
# 4575
# the guard by JOHN michael mcdonagh final shoot draft - conta
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Batman Year One_1672723_lemmas.txt
# 4568
# batman year one by Frank Miller sign in sign - up welcome !
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Inherent Vice_1791528_lemmas.txt
# 4456
# inherent vice screenplay by Paul Thomas Anderson base on the
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Colombiana_1657507_lemmas.txt
# 4333
# colombiana written by Robert Mark kamen &amp ; luc besson Au
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Barney s Version_1423894_lemmas.txt
# 4500
# barney 's version by Michael konyve base on the novel by mor
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Zootopia_2948356_lemmas.txt
# 4579
# zootopia written by Jared Bush &amp ; phil johnston Story by
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Scary Stories to Tell in the Dark_3387520_lemmas.txt
# 4656
# scary storues to tell in the dark written by Kevin & Dan hag
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/The Edge of Seventeen_1878870_lemmas.txt
# 4642
# bestie by Kelly fremon Craig January 3 , 2011 ext . norfolk
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/As Above So Below_2870612_lemmas.txt
# 4849
# as above , so below written by John erick dowdle Drew dowdle
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Celeste Jesse Forever_1405365_lemmas.txt
# 4482
# celeste and jesse forever written by rashida Jones &amp ; wi
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Up in the Air_1193138_lemmas.txt
# 4452
# up in the AIR written by Jason reitman &amp ; sheldon Turner
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Newton_6484982_lemmas.txt
# 4774
# ext . SMALL town STREET - day 1 a red , dusty road in a mini
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Mark Felt The Man Who Brought Down the White House_5175450_lemmas.txt
# 4618
# MARK felt - the man who bring down the white house by Peter
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Alice in Wonderland_1014759_lemmas.txt
# 4604
# Alice by Linda woolverton base on Alice 's adventure in wond
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Rise of the Planet of the Apes_1318514_lemmas.txt
# 4581
# rise of the planet of the ape written by Rick jaffa &amp ; a
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Jennifer s Body_1131734_lemmas.txt
# 4725
# jennifer' body written by Diablo cody 9/20/2007 int . leech
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/MacGruber_1470023_lemmas.txt
# 4656
# macgruber by will forte , John Solomon & jorma taccone super
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Good Vibrations_1920945_lemmas.txt
# 4580
# good vibration by Colin carberry and Glenn Patterson shoot s
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Frances Ha_2347569_lemmas.txt
# 4477
# france ha written by noah baumbach & greta gerwig overture :
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Black Panther_1825683_lemmas.txt
# 4687
# black panther written by Ryan coogler &amp ; Joe Robert Cole
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Y The Last Man_8042500_lemmas.txt
# 4822
# y the last man by Brian K. vaughan base on the series from v
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Shadow Dancer_1770734_lemmas.txt
# 4508
# shadow dancer by tom bradby Valerie hoskins Valerie hoskins
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Secretariat_1028576_lemmas.txt
# 4552
# iturn my screenplay inte a mp3 and it 's making money ] = tu
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Dunkirk_5013056_lemmas.txt
# 4848
# dunkirk by Christopher nolan D U N k I R k black screen : wa
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Hold the Dark_5057140_lemmas.txt
# 4512
# hold the dark base on the novel by William giraldi write for
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Bridget Jones s Baby_1473832_lemmas.txt
# 4723
# BRIDGET jones' baby by helen field and Dan mazer and Emma Th
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Dirty Girl_1107319_lemmas.txt
# 4643
# 7 / dirty girl by abe sylvia wga registered first draft Apri
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/This Is the End_1245492_lemmas.txt
# 4285
# not grey picture 6525 W. sunset Blvd. , Los Angeles , CA 900
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Ryan Hansen Solves Crimes on Television_7068580_lemmas.txt
# 4504
# ryan hansen solve crime on television * '' Jane d'oh ! " wri
# **************************************************
# /content/drive/MyDrive/W266_Movie_Data/raw_text_lemmas/raw_text_lemmas/Pacific Rim_1663662_lemmas.txt
# 5016
# pacific rim by Travis beacham preface : lexicon ( a suppleme
# **************************************************

# %%
len(lemma_text)
# Out:
# 30

# %% [markdown]
# # Functions to get the texts

# %%
def get_movie_title(script_txt_file):
    '''get the movie title without the unique identifier and _anno.txt suffix'''
    movie_title = script_txt_file.split('_')[0]
    return movie_title

def get_script_length(file_path, script_txt_file):
    '''calculate the number of lines in a BERT annotated script'''
    with open(str(file_path) + str(script_txt_file), 'r') as test_file:
        script_length = len(test_file.readlines())
    return script_length

def read_script(file_path, script_txt_file):
    '''read in the BERT annotated script'''
    script_text = open(str(file_path) + str(script_txt_file), 'r')
    # print(test_file.read())
    return script_text.read()

def count_script_elements(file_path, script_txt_file):
    '''count script elements such as dialog, text, speaker_heading, scene_heding'''
    script_element_dict = {}
    with open(str(file_path) + str(script_txt_file), 'r') as script_file:
        for line in script_file:
            script_element = line.split(':')[0]    
            if script_element not in script_element_dict:
                script_element_dict[script_element] = 1
            else:
                script_element_dict[script_element] += 1
    return script_element_dict

def identify_characters(file_path, script_txt_file):
    '''count number of characters and their speaking parts'''
    speaker_heading_dict = {}
    with open(str(file_path) + str(script_txt_file), 'r') as script_file:
        for line in script_file:
    
            # if the script element is 'speaker_heading' then that is a character
            if 'speaker_heading' in line.split(':')[0]:
                # some speaker_headings do not contain character names
                if re.search('[a-zA-Z]', line.split(':')[1]) != None:

                    # remove leading and trailing spaces and trailing newlines
                    character = line.split(':')[1].lstrip().rstrip().replace('\n', '')

                    # remove text that is not uppercase
                    character = ''.join(ch for ch in character if not ch.islower())

                    # remove (O.S.) off screen from character name
                    character = character.replace(' (O.S.)', '')

                    # remove trailing punctuation
                    character = character.rstrip('.').rstrip('?').rstrip('!')

                    ##### NEED TO ADD LOGIC TO DEAL WITH CONTINUOUS, CONTINUED, and CONT'D #####

                    if character not in speaker_heading_dict:
                        speaker_heading_dict[character] = 1
                    else:
                        speaker_heading_dict[character] += 1

    # remove characters that only have one speaking line
    character_dict = {k:v for k, v in speaker_heading_dict.items() if v > 1}
    print(f'character_dict length before removing single speaking lines: {len(speaker_heading_dict)}')
    print(f'character_dict length after removing single speaking lines: {len(character_dict)}')

    return character_dict

# %% [markdown]
# # Look into one raw text

# %%
subset_train_df['lemmas_raw_text'] = lemma_text
subset_train_df.head()
# Out:
#      Unnamed: 0             title  imdb_id  \
# 168         118         The Guard  1540133
# 129         320   Batman Year One  1672723
# 147         497     Inherent Vice  1791528
# 272         375        Colombiana  1657507
# 66          310  Barney s Version  1423894
#
#                                              bert_data  \
# 168  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 129  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 147  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 272  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 66   /content/drive/MyDrive/W266_Movie_Data/BERT_an...
#
#                                             lemma_data  \
# 168  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 129  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 147  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 272  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 66   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
#
#                                           plot_outline  \
# 168  Sergeant Gerry Boyle is a small-town Irish cop...
# 129  Two men come to Gotham City: Bruce Wayne after...
# 147  During the psychedelic 60s and 70s Larry "Doc"...
# 272  A young woman grows up to be a stone-cold assa...
# 66   Take a ride through the life and memories of B...
#
#                                            bert_dialog  \
# 168   Final Shooting Draft - Containing all revisio...
# 129   \n BATMAN YEAR ONE By Frank Miller\n \n Sign ...
# 147   screenplay by\n Paul Thomas Anderson\n based ...
# 272   \n Written by\n Robert Mark Kamen &amp; Luc B...
# 66    Barney's Version\n by\n Michael Konyves\n Bas...
#
#                                              bert_text  \
# 168   HELICOPTER SHOT -- a red car speeds through t...
# 129   LIGHTNING RIPS across a jet-black SKY.\n LIGH...
# 147   A sweet, young woman’s voice narrates.\n half...
# 272   ON A BLACK SCREEN\n CLOSE ON A PAGE OF A LARA...
# 66    A tumbler of Scotch. A half empty bottle of M...
#
#                                        lemmas_raw_text
# 168  the guard by JOHN michael mcdonagh final shoot...
# 129  batman year one by Frank Miller sign in sign -...
# 147  inherent vice screenplay by Paul Thomas Anders...
# 272  colombiana written by Robert Mark kamen &amp ;...
# 66   barney 's version by Michael konyve base on th...

# %% [markdown]
# # T5 for Generic Summarization - Model Loading

# %%
from transformers import T5Tokenizer, TFT5ForConditionalGeneration
t5model = TFT5ForConditionalGeneration.from_pretrained("t5-base")
t5tokenizer = T5Tokenizer.from_pretrained("t5-base")
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading tf_model.h5:   0%|          | 0.00/892M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at t5-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/tokenization_t5.py:163: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
from transformers import AutoConfig
config = AutoConfig.from_pretrained("t5-base")
config
# Out:
# T5Config {
#   "_name_or_path": "t5-base",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "relu",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": false,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.27.4",
#   "use_cache": true,
#   "vocab_size": 32128
# }

# %%
t5model.summary()
# Out:
# Model: "tft5_for_conditional_generation"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  shared (Embedding)          multiple                  24674304
#
#  encoder (TFT5MainLayer)     multiple                  109628544
#
#  decoder (TFT5MainLayer)     multiple                  137949312
#
# =================================================================
# Total params: 222,903,552
# Trainable params: 222,903,552
# Non-trainable params: 0
# _________________________________________________________________

# %%
# PROMPT = 'summarize: '
# T5ARTICLE_TO_SUMMARIZE = PROMPT + ARTICLE_TO_SUMMARIZE

subset_train_df['lemmas_raw_text_prompt'] = 'summarize: ' + subset_train_df['lemmas_raw_text']
subset_train_df.head()
# Out:
#      Unnamed: 0             title  imdb_id  \
# 168         118         The Guard  1540133
# 129         320   Batman Year One  1672723
# 147         497     Inherent Vice  1791528
# 272         375        Colombiana  1657507
# 66          310  Barney s Version  1423894
#
#                                              bert_data  \
# 168  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 129  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 147  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 272  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 66   /content/drive/MyDrive/W266_Movie_Data/BERT_an...
#
#                                             lemma_data  \
# 168  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 129  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 147  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 272  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 66   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
#
#                                           plot_outline  \
# 168  Sergeant Gerry Boyle is a small-town Irish cop...
# 129  Two men come to Gotham City: Bruce Wayne after...
# 147  During the psychedelic 60s and 70s Larry "Doc"...
# 272  A young woman grows up to be a stone-cold assa...
# 66   Take a ride through the life and memories of B...
#
#                                            bert_dialog  \
# 168   Final Shooting Draft - Containing all revisio...
# 129   \n BATMAN YEAR ONE By Frank Miller\n \n Sign ...
# 147   screenplay by\n Paul Thomas Anderson\n based ...
# 272   \n Written by\n Robert Mark Kamen &amp; Luc B...
# 66    Barney's Version\n by\n Michael Konyves\n Bas...
#
#                                              bert_text  \
# 168   HELICOPTER SHOT -- a red car speeds through t...
# 129   LIGHTNING RIPS across a jet-black SKY.\n LIGH...
# 147   A sweet, young woman’s voice narrates.\n half...
# 272   ON A BLACK SCREEN\n CLOSE ON A PAGE OF A LARA...
# 66    A tumbler of Scotch. A half empty bottle of M...
#
#                                        lemmas_raw_text  \
# 168  the guard by JOHN michael mcdonagh final shoot...
# 129  batman year one by Frank Miller sign in sign -...
# 147  inherent vice screenplay by Paul Thomas Anders...
# 272  colombiana written by Robert Mark kamen &amp ;...
# 66   barney 's version by Michael konyve base on th...
#
#                                 lemmas_raw_text_prompt
# 168  summarize: the guard by JOHN michael mcdonagh ...
# 129  summarize: batman year one by Frank Miller sig...
# 147  summarize: inherent vice screenplay by Paul Th...
# 272  summarize: colombiana written by Robert Mark k...
# 66   summarize: barney 's version by Michael konyve...

# %%
subset_train_df.reset_index()
# Out:
#     index  Unnamed: 0                                              title  \
# 0     168         118                                          The Guard
# 1     129         320                                    Batman Year One
# 2     147         497                                      Inherent Vice
# 3     272         375                                         Colombiana
# 4      66         310                                   Barney s Version
# 5     338         264                                           Zootopia
# 6     255          62                  Scary Stories to Tell in the Dark
# 7     349         119                              The Edge of Seventeen
# 8     126         308                                  As Above So Below
# 9     261         359                              Celeste Jesse Forever
# 10    209         228                                      Up in the Air
# 11     89          14                                             Newton
# 12     42         530  Mark Felt The Man Who Brought Down the White H...
# 13    220         305                                Alice in Wonderland
# 14    267          46                     Rise of the Planet of the Apes
# 15    213         508                                    Jennifer s Body
# 16    117         525                                          MacGruber
# 17    144         460                                    Good Vibrations
# 18    130         423                                         Frances Ha
# 19    174         345                                      Black Panther
# 20    288         263                                     Y The Last Man
# 21     37          75                                      Shadow Dancer
# 22    263          59                                        Secretariat
# 23    336         387                                            Dunkirk
# 24    124         449                                      Hold the Dark
# 25    295         348                               Bridget Jones s Baby
# 26    346         411                                         Dirty Girl
# 27    188         239                                    This Is the End
# 28     57          79            Ryan Hansen Solves Crimes on Television
# 29    183          27                                        Pacific Rim
#
#     imdb_id                                          bert_data  \
# 0   1540133  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 1   1672723  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 2   1791528  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 3   1657507  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 4   1423894  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 5   2948356  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 6   3387520  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 7   1878870  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 8   2870612  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 9   1405365  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 10  1193138  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 11  6484982  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 12  5175450  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 13  1014759  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 14  1318514  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 15  1131734  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 16  1470023  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 17  1920945  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 18  2347569  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 19  1825683  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 20  8042500  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 21  1770734  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 22  1028576  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 23  5013056  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 24  5057140  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 25  1473832  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 26  1107319  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 27  1245492  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 28  7068580  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 29  1663662  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
#
#                                            lemma_data  \
# 0   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 1   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 2   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 3   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 4   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 5   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 6   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 7   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 8   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 9   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 10  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 11  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 12  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 13  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 14  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 15  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 16  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 17  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 18  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 19  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 20  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 21  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 22  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 23  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 24  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 25  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 26  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 27  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 28  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 29  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
#
#                                          plot_outline  \
# 0   Sergeant Gerry Boyle is a small-town Irish cop...
# 1   Two men come to Gotham City: Bruce Wayne after...
# 2   During the psychedelic 60s and 70s Larry "Doc"...
# 3   A young woman grows up to be a stone-cold assa...
# 4   Take a ride through the life and memories of B...
# 5   From the largest elephant to the smallest shre...
# 6   It's 1968 in America. Change is blowing in the...
# 7   Everyone knows that growing up is hard, and li...
# 8   Miles of twisting catacombs lie beneath the st...
# 9   Celeste and Jesse have been best friends forev...
# 10  Ryan Bingham is a corporate downsizing expert ...
# 11  As India, the world's largest democracy, brace...
# 12  1972. Following the death of fifty year FBI Di...
# 13  Alice, an unpretentious and individual 19-year...
# 14  At the story's heart is Caesar (Andy Serkis), ...
# 15  Nerdy, reserved bookworm Needy Lesnicki, and a...
# 16  In the Dzhugdzhur Mountains, Eastern Siberia, ...
# 17  In 1970s Belfast, Terri Hooley is an idealisti...
# 18  Frances lives in New York, but she doesn't rea...
# 19  After the events of Captain America: Civil War...
# 20  Set in a post-apocalyptic world where all bein...
# 21  In 1993, the IRA member Collette is arrested i...
# 22  Housewife and mother Penny Chenery agrees to t...
# 23  May/June 1940. Four hundred thousand British a...
# 24  Retired naturalist and wolf expert Russell Cor...
# 25  On her forty-third birthday, Bridget Jones (Re...
# 26  A comedic story of the search for identity and...
# 27  All Jay Baruchel expected coming to LA was a f...
# 28  In this series, the LAPD thinks it's a good id...
# 29  When monstrous creatures, known as Kaiju, star...
#
#                                           bert_dialog  \
# 0    Final Shooting Draft - Containing all revisio...
# 1    \n BATMAN YEAR ONE By Frank Miller\n \n Sign ...
# 2    screenplay by\n Paul Thomas Anderson\n based ...
# 3    \n Written by\n Robert Mark Kamen &amp; Luc B...
# 4    Barney's Version\n by\n Michael Konyves\n Bas...
# 5    \n Written by\n Jared Bush &amp; Phil Johnsto...
# 6    Written by\n Kevin & Dan Hageman\n Story by\n...
# 7    by\n Kelly Fremon Craig\n January 3, 2011\n I...
# 8    Written by\n John Erick Dowdle\n Drew Dowdle\...
# 9    \n \n Written by\n \n Rashida Jones &amp; Wil...
# 10   \n Written by\n Jason Reitman &amp; Sheldon T...
# 11   Humara neta kaisa ho? Mangal Netam\n jaisa ho...
# 12   \n by\n Peter Landesman\n President Richard N...
# 13   Alice\n by\n Linda Woolverton\n Based on\n Al...
# 14   \n \n Written by\n Rick Jaffa &amp; Amanda Si...
# 15   \n \n \n Written by\n Diablo Cody\n \n \n \n ...
# 16   MacGruber\n by\n Will Forte, John Solomon & J...
# 17   Good Vibrations\n by\n Colin Carberry and Gle...
# 18   Written by\n Noah Baumbach & Greta Gerwig\n O...
# 19   \n \n \n \n Written by\n Ryan Coogler &amp; J...
# 20   by\n Brian K. Vaughan\n Based on the series f...
# 21   Valerie Hoskins\n Valerie Hoskins Associates ...
# 22   Iturned my screenplay inte a MP3\n and It's M...
# 23   by\n Christopher Nolan\n Super title tries th...
# 24   based on the novel by\n William Giraldi\n wri...
# 25   by\n Helen Fielding\n and\n Dan Mazer\n and\n...
# 26   7 /\n By\n Abe Sylvia\n First Draft April 14,...
# 27   nt Grey Pictures\n Los Angeles, CA 90028\n 32...
# 28   “Jane D'Oh!"\n Written by\n Rawson Marshall T...
# 29   by\n Travis Beacham\n (A supplementary guide ...
#
#                                             bert_text  \
# 0    HELICOPTER SHOT -- a red car speeds through t...
# 1    LIGHTNING RIPS across a jet-black SKY.\n LIGH...
# 2    A sweet, young woman’s voice narrates.\n half...
# 3    ON A BLACK SCREEN\n CLOSE ON A PAGE OF A LARA...
# 4    A tumbler of Scotch. A half empty bottle of M...
# 5    We hear the feral, primeval sounds of a jungl...
# 6    TO TELL IN THE DARK\n Settled on a fork of th...
# 7    A murky green pond dotted with floating litte...
# 8    Camera powers up, jostles around until it set...
# 9    A progression of images of CELESTE and JESSE,...
# 10   A SPOTLIGHT reveals RYAN BINGHAM standing at ...
# 11   A red, dusty road in a mining town.\n A POLIT...
# 12   Now a rhythmic, accelerating anthology -- foo...
# 13   Warm light shines from the study of the graci...
# 14   RISE OF THE PLANET OF THE APES\n No. They bel...
# 15   ANITA "NEEDY" LESNICKI, 17, sits on her hospi...
# 16   CLOSE UP words in Russian can be heard throug...
# 17   A beautiful ordered garden. The colours are f...
# 18   IMAGES of Tompkins Square Park. Over the tabl...
# 19   A dark screen is lit up by twinkling stars .\...
# 20   Open hard on the passenger seat of a speeding...
# 21   Lucas, Alexander Whitley, 14 Vernon Street, L...
# 22   A manicured, upper-middle-class neighborhood ...
# 23   WATER slaps hollow metal, metal knocks CREAKI...
# 24   O unteachably after evil, but uttering truth....
# 25   Based on the characters and story created by ...
# 26   A PRETTY BLONDE GIRL takes a seat with her fr...
# 27   We see the words appear on screen CRAIG ROBIN...
# 28   RYAN HANSEN, shirtless and lightly perspiring...
# 29   * Anteverse. the older, parent universe on th...
#
#                                       lemmas_raw_text  \
# 0   the guard by JOHN michael mcdonagh final shoot...
# 1   batman year one by Frank Miller sign in sign -...
# 2   inherent vice screenplay by Paul Thomas Anders...
# 3   colombiana written by Robert Mark kamen &amp ;...
# 4   barney 's version by Michael konyve base on th...
# 5   zootopia written by Jared Bush &amp ; phil joh...
# 6   scary storues to tell in the dark written by K...
# 7   bestie by Kelly fremon Craig January 3 , 2011 ...
# 8   as above , so below written by John erick dowd...
# 9   celeste and jesse forever written by rashida J...
# 10  up in the AIR written by Jason reitman &amp ; ...
# 11  ext . SMALL town STREET - day 1 a red , dusty ...
# 12  MARK felt - the man who bring down the white h...
# 13  Alice by Linda woolverton base on Alice 's adv...
# 14  rise of the planet of the ape written by Rick ...
# 15  jennifer' body written by Diablo cody 9/20/200...
# 16  macgruber by will forte , John Solomon & jorma...
# 17  good vibration by Colin carberry and Glenn Pat...
# 18  france ha written by noah baumbach & greta ger...
# 19  black panther written by Ryan coogler &amp ; J...
# 20  y the last man by Brian K. vaughan base on the...
# 21  shadow dancer by tom bradby Valerie hoskins Va...
# 22  iturn my screenplay inte a mp3 and it 's makin...
# 23  dunkirk by Christopher nolan D U N k I R k bla...
# 24  hold the dark base on the novel by William gir...
# 25  BRIDGET jones' baby by helen field and Dan maz...
# 26  7 / dirty girl by abe sylvia wga registered fi...
# 27  not grey picture 6525 W. sunset Blvd. , Los An...
# 28  ryan hansen solve crime on television * '' Jan...
# 29  pacific rim by Travis beacham preface : lexico...
#
#                                lemmas_raw_text_prompt
# 0   summarize: the guard by JOHN michael mcdonagh ...
# 1   summarize: batman year one by Frank Miller sig...
# 2   summarize: inherent vice screenplay by Paul Th...
# 3   summarize: colombiana written by Robert Mark k...
# 4   summarize: barney 's version by Michael konyve...
# 5   summarize: zootopia written by Jared Bush &amp...
# 6   summarize: scary storues to tell in the dark w...
# 7   summarize: bestie by Kelly fremon Craig Januar...
# 8   summarize: as above , so below written by John...
# 9   summarize: celeste and jesse forever written b...
# 10  summarize: up in the AIR written by Jason reit...
# 11  summarize: ext . SMALL town STREET - day 1 a r...
# 12  summarize: MARK felt - the man who bring down ...
# 13  summarize: Alice by Linda woolverton base on A...
# 14  summarize: rise of the planet of the ape writt...
# 15  summarize: jennifer' body written by Diablo co...
# 16  summarize: macgruber by will forte , John Solo...
# 17  summarize: good vibration by Colin carberry an...
# 18  summarize: france ha written by noah baumbach ...
# 19  summarize: black panther written by Ryan coogl...
# 20  summarize: y the last man by Brian K. vaughan ...
# 21  summarize: shadow dancer by tom bradby Valerie...
# 22  summarize: iturn my screenplay inte a mp3 and ...
# 23  summarize: dunkirk by Christopher nolan D U N ...
# 24  summarize: hold the dark base on the novel by ...
# 25  summarize: BRIDGET jones' baby by helen field ...
# 26  summarize: 7 / dirty girl by abe sylvia wga re...
# 27  summarize: not grey picture 6525 W. sunset Blv...
# 28  summarize: ryan hansen solve crime on televisi...
# 29  summarize: pacific rim by Travis beacham prefa...

# %%
list_of_candidates = []
for i in range(subset_train_df.shape[0]):
# for i in range(df.shape[0]):
    print(i)
    prompt = subset_train_df['lemmas_raw_text_prompt'].iloc[i]
    # print(prompt)
    inputs = t5tokenizer(prompt, max_length=1024, truncation=True, return_tensors="tf")
    summary_ids = t5model.generate(inputs["input_ids"]
                                        , max_length = 256
                                        , min_length = 94
                                        , no_repeat_ngram_size = 3
                                        , num_beams = 4)
    candidate = t5tokenizer.batch_decode(summary_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)
    list_of_candidates.append(candidate)
    pprint.pprint(candidate[0], compact=True)
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
# 0
# ("the guard's final shoot draft - contain all revision January 2010 reprisal "
#  'film / element picture 21 mespil Road Dublin 4 Ireland . int . open title - '
#  'day 11 overhead shot -- boyle asleep on he bed . wearing only blue-and- '
#  'yellow Marks & Spencer y-front . and a white undershirt . close on -- a navy '
#  'tunic jacket . with three chevron buttoned up over he paunch .')
# 1
# ('batman year one screenplay by frank miller fade in . close batman season one '
#  ". bruce wayne's apartment is a claustrophobic . room of a obsessive "
#  "compulsive . but he manages to find a job he'd like to do . little al, a "
#  'gigantic , early middle - age black man .')
# 2
# ('inherent vice screenplay by Paul Thomas Anderson base on the novel by Thomas '
#  'pynchon this script be the confidential and proprietary property of Warner '
#  'bros . picture and no portion of it may be perform , distribute , reproduce '
#  ', use , quote or publish without prior write permission . final shoot script '
#  "August 7 , 2013 warner bros. picture inc . ''2013 4000 Warner boulevard "
#  'warner brothers . and ent . burbank , California 91522 all rights reserved '
#  'over black')
# 3
# ("fabio and don luis have been together since the age of 10 . don't know how "
#  "many times we should have been dead . 'i be go to miss you,' says don, 'you "
#  "can't do this thing if you be not a hundred percent' 'it's not my thing "
#  "anymore,' he tells his daughter . the colombian footballer is a 'real man' - "
#  "he's a doctor and a lawyer .")
# 4
# ("barney 's version by michael konyve based on the novel by mordecai richler "
#  'white . barney is the father of kate minor, who has a heart attack . he is '
#  'the son of a convicted felon who was sentenced to life in prison for a '
#  "drug-related sex offence . his version was adapted from the novel's first "
#  'novel .')
# 5
# ('zootopia written by jared bush &amp; phil johnston Story by Byron Howard . a '
#  'world where prey be scared of predator . and predator have a uncontrollable '
#  'biological urge to maim and maul and ... the timpani crescendos . young judy '
#  "( cont 'd ) and every young mammal have multitudinous opportunity .")
# 6
# ('scary storues to tell in the dark was written by Kevin & Dan hageman . the '
#  'series opens with a series of open shots of a town in decline . a disc '
#  "jockey, a swastika, and a ghost town are among the scenes . donovan's "
#  "''season of the witch'' is a haunting tale of san francisco .")
# 7
# ('nadine rostami ( 16 ) skinny , self - conscious posture , a face that have '
#  'not quite grown into her nose . krista ( 6 ) chubby , glass a inch thick , '
#  'play barby together . they are inseparable from the day they met back in the '
#  'spring of 2nd grade . their friendship has been a constant .')
# 8
# ('scarlett durang, a 20-year-old british archaeologist, is en route to the '
#  'habala region where they have ordered the destruction of a network of caves '
#  'at sundown . she and her husband, reza, have already cleared the area . they '
#  'are surrounded by a swarm of iranian tourists . a group of britons are '
#  'preparing to visit the caves .')
# 9
# ('celeste and jesse forever written by rashida Jones &amp; will mccormack '
#  '5.01. 11 1 montage over the open credit to sunny levine\'s " love 1 rhino " '
#  'Visual media evolve with they throughout the year . a1 celeste be a chronic '
#  'overachiever . and he be sweet , goofy and funny . they be best friend but '
#  "it's clear that jesses wish they be more .")
# 10
# ('up in the AIR written by Jason reitman &amp ; sheldon Turner secure you own '
#  'mask before assist other . - common pre-flight instruction 1. a spotlight '
#  'reveal ryan bingham . unzip a backpack and set it down beside he . Ryan how '
#  'much do you life weigh ? now . start add the larger stuff . int SMALL '
#  'conference room - day two word - subordinate chic .')
# 11
# ('the jeep move through the market place . his 40 supporter be on 15 '
#  'motorcycle bear bandannas and flag in he party color , yellow . they ride '
#  'slowly in front of the chariot shouting slogan . chorus humara neta kaisa ho '
#  '? mangal netam . Zindabad ! ext . SMALL town STREET - day 1 a red , dusty '
#  'road in a mining town .')
# 12
# ('felt and folger cross the potomac on their way to the white house . a smudge '
#  "on Dean's shoe and a patch of perspiration on ehrlichman's forehead capture "
#  'the moment . mitchell and ehrlichman have a rare and train hyper-awareness . '
#  "the president's re-election campaign was filmed on tuesday in washington, "
#  'd.c.')
# 13
# ("helen kingsley's daughter alice is on the verge of womanhood . she is a "
#  "'dodo bird', 'a rabbit in a waistcoat' and a smile cat . alice's mother is "
#  'grumpy and tired as she mother fusses with her wild mane of blonde hair . '
#  "'all the best people be,' she says .")
# 14
# ('rise of the planet of the ape written by Rick jaffa &amp; amanda Silver '
#  'previous revision by Jamie moss January 8th, 2010 eye . expressive , alive . '
#  '. the chimpanzee - a female chimp in a gas mask . caroline nanotherapy , '
#  'beta version . Tuesday , march 10 . 2011 . will rodman - late twenty .')
# 15
# ('int . leech lake women\' correctional hospital - day anita " needy " '
#  "lesnicki , 17 , sit on her hospital bed in pajamas . she 'is a plain - face "
#  'girl with a haunt expression . as she stares out the window , she wind color '
#  'yarn around a pair of popsicle stick to create a " god \'s eye . "')
# 16
# ('voice over cb ( in Russian ) ( static ) wombat, this be eagle nest . a few '
#  'word in Russian can be heard through the static . int . military truck -- '
#  'cab -- day the camera track along the front of the truck . where we find the '
#  'body of another dead soldier before landing on a pair of boot leaning up '
#  'against the front . we find a wild - eye bald man with a pony tail .')
# 17
# ("int terri's world - night and day - become the soundtrack as the arrow take "
#  'us on a accelerate journey into her world . from agricultural show to sheep '
#  'flee a bomb blast , from schoolkid dance at a fote to a line of monk be '
#  'frisk by british soldier . mavis and GEORGE - whose bear , as much as he '
#  'waistcoat and collarless shirt , mark he as out of he time')
# 18
# ('france ha written by noah baumbach & greta gerwig overture : image of '
#  'tompkin Square Park . over the tableaus we 1 hear two woman talk and laugh . '
#  'ext . park . morning 2 we find france and Sophie , both 27 , set up a little '
#  'performance space in front of a statue . france ( alone now ) give we ( '
#  'laugh ) come on .')
# 19
# ('black panther written by Ryan coogler &amp; Joe Robert Cole ext . deep space '
#  'a dark screen be light up by twinkle star . son Baba ? father yes , my son ? '
#  'son the story of home . a meteorite drift into frame , head towards tiny '
#  'Earth off in the distance . father million of year ago , a . meteoritite '
#  'make of vibranium , the strongest substance in the universe . strike the '
#  'continent of Africa affect the')
# 20
# ('y the last man by Brian K. vaughan base on the series from vertigo Comics . '
#  "a male teenager be slumped against a blood-stain window . the late teen's "
#  'mother be cut off mid-sentence by exploding glass . two more dead boy in the '
#  'back seat of the minivan . inside a tastefully decorate office, we learn '
#  'that the voice behind this non sequitur belong to yorick brown .')
# 21
# ("tom bradby's shadow dancer is based on he novel . he was written by vale "
#  "hoskins associates in belfast, london . the book is a children's book about "
#  "a riot in a city of civil strife . it's the story of a 12-year-old collette "
#  'mcveigh and her father, gerry senior .')
# 22
# ("iturn my screenplay inte a mp3 and it 's making money' secretariat randall "
#  'wallace revision of a Mike Rich original February 3 , 2009 page 1 of 113 '
#  'fade in . penny chenery tweedy , 40 . , intelligent , elegant , beautiful , '
#  'walk down the staircase of her precisely arrange home . int chenerie home , '
#  'denver , colorado .')
# 23
# ('british and french armies are trapped at dunkirk . one man clambers over a '
#  'dune, undoes his belt, drops trousers and squats . another man, tommy '
#  'anglais, grabs a water can and scoops sand over the body . he squints and '
#  "runs to the beach - a long , widest beach he's ever seen .")
# 24
# ('this appear on black screen : o unteachably after evil , but uttering truth '
#  '. a wolf howls from some far unknowable place ... but then morphs into an '
#  'droning electric buzz . and a boy ( 7 ) kneels to pack a mound of snow . but '
#  'a woman ( 30 ) looks out at something . freezes .')
# 25
# ("BRIDGET jones' baby by helen field and Dan mazer and Emma Thompson base on "
#  'the character and story create by . heleen field final shoot script 8th '
#  "January 2016 '' 2016 universal studios . all rights reserved . shoot script "
#  '. 1 1a 1 aa omitted 1 ext london . day . 2 shazzer , early forty , and she '
#  'folk singer husband fergus , scurry down the aisle')
# 26
# ("'dirty girl' is that girl that every high school have . the one who be more "
#  'mature , more sexual , and somehow , just inexplicably dirty . if you do not '
#  'stay busy . and practice abstinence , you could end up like this guy my mom '
#  'know . who can give me a example of a good choice ? danielle, a skinny girl '
#  'with disproportionately large breast .')
# 27
# ('jay baruchel, jonah hill, jame franco and craig robinson on different talk '
#  'storey and talk about their fai . humble and self - - deprecatit footage of '
#  "the guy go . he eats at canter 's . jay ( cont 'd ) just get in . and then "
#  'sleeps the next day .')
# 28
# ("ryan hansen solves crime on television * '' Jane d'oh !'' written by rawson "
#  'Marshall thurber episode # 102 February lst , 2017 * though you probably be '
#  "probably watch this on steal chinese internet and that 's cool too . he "
#  'huffs and puffs he way up this iconic " hike " trail in the Hollywood hill .')
# 29
# ('the jaeger / pilot interface suit design to monitor vital sign and to '
#  'translate nerve signal to piloting input * ghost-drift . a kind of '
#  'quasi-telepathic vision share ( by party with a pre-existing pon connection '
#  ') without the aid of a hard neural interface . the osaka exclusion zone is '
#  "cosdec 's ultra-secret research facility and surveillance station .")

# %%
len(list_of_candidates)

subset_train_df['t5_generation'] = list_of_candidatesb

# %%
subset_train_df.head()
subset_train_df.to_csv('subset_train_df_with_t5.csv')

# %%
test = pd.read_csv('subset_train_df_with_t5.csv')
# Out:
#    Unnamed: 0.1  Unnamed: 0             title  imdb_id  \
# 0           168         118         The Guard  1540133
# 1           129         320   Batman Year One  1672723
# 2           147         497     Inherent Vice  1791528
# 3           272         375        Colombiana  1657507
# 4            66         310  Barney s Version  1423894
#
#                                            bert_data  \
# 0  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 1  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 2  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 3  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 4  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
#
#                                           lemma_data  \
# 0  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 1  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 2  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 3  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 4  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
#
#                                         plot_outline  \
# 0  Sergeant Gerry Boyle is a small-town Irish cop...
# 1  Two men come to Gotham City: Bruce Wayne after...
# 2  During the psychedelic 60s and 70s Larry "Doc"...
# 3  A young woman grows up to be a stone-cold assa...
# 4  Take a ride through the life and memories of B...
#
#                                          bert_dialog  \
# 0   Final Shooting Draft - Containing all revisio...
# 1   \n BATMAN YEAR ONE By Frank Miller\n \n Sign ...
# 2   screenplay by\n Paul Thomas Anderson\n based ...
# 3   \n Written by\n Robert Mark Kamen &amp; Luc B...
# 4   Barney's Version\n by\n Michael Konyves\n Bas...
#
#                                            bert_text  \
# 0   HELICOPTER SHOT -- a red car speeds through t...
# 1   LIGHTNING RIPS across a jet-black SKY.\n LIGH...
# 2   A sweet, young woman’s voice narrates.\n half...
# 3   ON A BLACK SCREEN\n CLOSE ON A PAGE OF A LARA...
# 4   A tumbler of Scotch. A half empty bottle of M...
#
#                                      lemmas_raw_text  \
# 0  the guard by JOHN michael mcdonagh final shoot...
# 1  batman year one by Frank Miller sign in sign -...
# 2  inherent vice screenplay by Paul Thomas Anders...
# 3  colombiana written by Robert Mark kamen &amp ;...
# 4  barney 's version by Michael konyve base on th...
#
#                               lemmas_raw_text_prompt  \
# 0  summarize: the guard by JOHN michael mcdonagh ...
# 1  summarize: batman year one by Frank Miller sig...
# 2  summarize: inherent vice screenplay by Paul Th...
# 3  summarize: colombiana written by Robert Mark k...
# 4  summarize: barney 's version by Michael konyve...
#
#                                        t5_generation
# 0  ["the guard's final shoot draft - contain all ...
# 1  ["batman year one screenplay by frank miller f...
# 2  ["inherent vice screenplay by Paul Thomas Ande...
# 3  ["fabio and don luis have been together since ...
# 4  ["barney 's version by michael konyve based on...

# %%
subset_train_df.head()
# Out:
#      Unnamed: 0             title  imdb_id  \
# 168         118         The Guard  1540133
# 129         320   Batman Year One  1672723
# 147         497     Inherent Vice  1791528
# 272         375        Colombiana  1657507
# 66          310  Barney s Version  1423894
#
#                                              bert_data  \
# 168  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 129  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 147  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 272  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 66   /content/drive/MyDrive/W266_Movie_Data/BERT_an...
#
#                                             lemma_data  \
# 168  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 129  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 147  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 272  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 66   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
#
#                                           plot_outline  \
# 168  Sergeant Gerry Boyle is a small-town Irish cop...
# 129  Two men come to Gotham City: Bruce Wayne after...
# 147  During the psychedelic 60s and 70s Larry "Doc"...
# 272  A young woman grows up to be a stone-cold assa...
# 66   Take a ride through the life and memories of B...
#
#                                            bert_dialog  \
# 168   Final Shooting Draft - Containing all revisio...
# 129   \n BATMAN YEAR ONE By Frank Miller\n \n Sign ...
# 147   screenplay by\n Paul Thomas Anderson\n based ...
# 272   \n Written by\n Robert Mark Kamen &amp; Luc B...
# 66    Barney's Version\n by\n Michael Konyves\n Bas...
#
#                                              bert_text  \
# 168   HELICOPTER SHOT -- a red car speeds through t...
# 129   LIGHTNING RIPS across a jet-black SKY.\n LIGH...
# 147   A sweet, young woman’s voice narrates.\n half...
# 272   ON A BLACK SCREEN\n CLOSE ON A PAGE OF A LARA...
# 66    A tumbler of Scotch. A half empty bottle of M...
#
#                                        lemmas_raw_text  \
# 168  the guard by JOHN michael mcdonagh final shoot...
# 129  batman year one by Frank Miller sign in sign -...
# 147  inherent vice screenplay by Paul Thomas Anders...
# 272  colombiana written by Robert Mark kamen &amp ;...
# 66   barney 's version by Michael konyve base on th...
#
#                                 lemmas_raw_text_prompt  \
# 168  summarize: the guard by JOHN michael mcdonagh ...
# 129  summarize: batman year one by Frank Miller sig...
# 147  summarize: inherent vice screenplay by Paul Th...
# 272  summarize: colombiana written by Robert Mark k...
# 66   summarize: barney 's version by Michael konyve...
#
#                                          t5_generation
# 168  [the guard's final shoot draft - contain all r...
# 129  [batman year one screenplay by frank miller fa...
# 147  [inherent vice screenplay by Paul Thomas Ander...
# 272  [fabio and don luis have been together since t...
# 66   [barney 's version by michael konyve based on ...

# %%
subset_train_df['t5_generation_str'] = subset_train_df['t5_generation'].apply(lambda x: ','.join(map(str, x)))

subset_train_df.head()
# Out:
#      Unnamed: 0             title  imdb_id  \
# 168         118         The Guard  1540133
# 129         320   Batman Year One  1672723
# 147         497     Inherent Vice  1791528
# 272         375        Colombiana  1657507
# 66          310  Barney s Version  1423894
#
#                                              bert_data  \
# 168  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 129  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 147  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 272  /content/drive/MyDrive/W266_Movie_Data/BERT_an...
# 66   /content/drive/MyDrive/W266_Movie_Data/BERT_an...
#
#                                             lemma_data  \
# 168  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 129  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 147  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 272  /content/drive/MyDrive/W266_Movie_Data/raw_tex...
# 66   /content/drive/MyDrive/W266_Movie_Data/raw_tex...
#
#                                           plot_outline  \
# 168  Sergeant Gerry Boyle is a small-town Irish cop...
# 129  Two men come to Gotham City: Bruce Wayne after...
# 147  During the psychedelic 60s and 70s Larry "Doc"...
# 272  A young woman grows up to be a stone-cold assa...
# 66   Take a ride through the life and memories of B...
#
#                                            bert_dialog  \
# 168   Final Shooting Draft - Containing all revisio...
# 129   \n BATMAN YEAR ONE By Frank Miller\n \n Sign ...
# 147   screenplay by\n Paul Thomas Anderson\n based ...
# 272   \n Written by\n Robert Mark Kamen &amp; Luc B...
# 66    Barney's Version\n by\n Michael Konyves\n Bas...
#
#                                              bert_text  \
# 168   HELICOPTER SHOT -- a red car speeds through t...
# 129   LIGHTNING RIPS across a jet-black SKY.\n LIGH...
# 147   A sweet, young woman’s voice narrates.\n half...
# 272   ON A BLACK SCREEN\n CLOSE ON A PAGE OF A LARA...
# 66    A tumbler of Scotch. A half empty bottle of M...
#
#                                        lemmas_raw_text  \
# 168  the guard by JOHN michael mcdonagh final shoot...
# 129  batman year one by Frank Miller sign in sign -...
# 147  inherent vice screenplay by Paul Thomas Anders...
# 272  colombiana written by Robert Mark kamen &amp ;...
# 66   barney 's version by Michael konyve base on th...
#
#                                 lemmas_raw_text_prompt  \
# 168  summarize: the guard by JOHN michael mcdonagh ...
# 129  summarize: batman year one by Frank Miller sig...
# 147  summarize: inherent vice screenplay by Paul Th...
# 272  summarize: colombiana written by Robert Mark k...
# 66   summarize: barney 's version by Michael konyve...
#
#                                          t5_generation  \
# 168  [the guard's final shoot draft - contain all r...
# 129  [batman year one screenplay by frank miller fa...
# 147  [inherent vice screenplay by Paul Thomas Ander...
# 272  [fabio and don luis have been together since t...
# 66   [barney 's version by michael konyve based on ...
#
#                                      t5_generation_str
# 168  the guard's final shoot draft - contain all re...
# 129  batman year one screenplay by frank miller fad...
# 147  inherent vice screenplay by Paul Thomas Anders...
# 272  fabio and don luis have been together since th...
# 66   barney 's version by michael konyve based on t...

# %%
rouge = evaluate.load('rouge')
references = list(subset_train_df['plot_outline'])
pred =       list(subset_train_df['t5_generation_str'])
# T5
results = rouge.compute(predictions=pred, references=references)
print('base t5 with n=30 compared with outline, ', results)
# Out:
# base t5 with n=30 compared with outline,  {'rouge1': 0.1852579479351284, 'rouge2': 0.01797985622544701, 'rougeL': 0.11554045940424346, 'rougeLsum': 0.11445694008626571}

# %% [markdown]
# pred_base_ada_94,  {'rouge1': 0.1852579479351284, 'rouge2': 0.01797985622544701, 'rougeL': 0.11554045940424346, 'rougeLsum': 0.11445694008626571}

# %%
rouge = evaluate.load('rouge')
references = list(subset_train_df['plot_outline'])
pred =       list(subset_train_df['title'])
# T5
results = rouge.compute(predictions=pred, references=references)
print('title, ', results)
# Out:
# title,  {'rouge1': 0.041811426049666034, 'rouge2': 0.014025394577675314, 'rougeL': 0.04032699063468995, 'rougeLsum': 0.039798010939398915}
